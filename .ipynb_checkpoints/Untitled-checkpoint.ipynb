# %%
import numpy as np
import pandas as pd
import matplotlib
import seaborn as sns

# %%
# %matplotlib inline

# %%
students_perdormance = pd.read_csv('C:/Users/filip/ML/static//StudentsPerformance.csv')

# %%
students_perdormance.shape
# Out:
# 8000

# %%
students_perdormance.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
students_perdormance.size
# Out:
# 8000

# %%
students_perdormance.iloc[:6]
# Out:
#    gender race/ethnicity parental level of education         lunch  \
# 0  female        group B           bachelor's degree      standard
# 1  female        group C                some college      standard
# 2  female        group B             master's degree      standard
# 3    male        group A          associate's degree  free/reduced
# 4    male        group C                some college      standard
# 5  female        group B          associate's degree      standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 3                    none          47             57             44
# 4                    none          76             78             75
# 5                    none          71             83             78

# %%
students_perdormance_whis_makes = students_perdormance.iloc[[0, 3, 4, 7 , 8]]

# %%
students_perdormance_whis_makes.index = ['gthdsq', 'dnjhjq', 'nhtnbq', 'xtnd`hnsq', 'gznsq']
students_perdormance_whis_makes
# Out:
#            gender race/ethnicity parental level of education         lunch  \
# gthdsq     female        group B           bachelor's degree      standard
# dnjhjq       male        group A          associate's degree  free/reduced
# nhtnbq       male        group C                some college      standard
# xtnd`hnsq    male        group B                some college  free/reduced
# gznsq        male        group D                 high school  free/reduced
#
#           test preparation course  math score  reading score  writing score
# gthdsq                       none          72             72             74
# dnjhjq                       none          47             57             44
# nhtnbq                       none          76             78             75
# xtnd`hnsq                    none          40             43             39
# gznsq                   completed          64             64             67

# %%
students_perdormance_whis_makes.loc[['gthdsq', 'gznsq'],['lunch', 'gender']]
# Out:
#                lunch  gender
# gthdsq      standard  female
# gznsq   free/reduced    male

# %%
test_1_4 = pd.read_csv('C:/Users/filip/ML/static//titanic.csv')

# %%
test_1_4.dtypes
# Out:
# PassengerId      int64
# Survived         int64
# Pclass           int64
# Name            object
# Sex             object
# Age            float64
# SibSp            int64
# Parch            int64
# Ticket          object
# Fare           float64
# Cabin           object
# Embarked        object
# dtype: object

# %%
wr = students_perdormance['writing score'].mean()
wr
# Out:
# 68.054

# %%
query = (students_perdormance['writing score'] > wr) & (students_perdormance.gender == 'female')

# %%
students_perdormance.loc[query].head()
# Out:
#    gender race/ethnicity parental level of education     lunch  \
# 0  female        group B           bachelor's degree  standard
# 1  female        group C                some college  standard
# 2  female        group B             master's degree  standard
# 5  female        group B          associate's degree  standard
# 6  female        group B                some college  standard
#
#   test preparation course  math score  reading score  writing score
# 0                    none          72             72             74
# 1               completed          69             90             88
# 2                    none          90             95             93
# 5                    none          71             83             78
# 6               completed          88             95             92

# %%
new_lunch = (students_perdormance['lunch'] == 'free/reduced')
students_perdormance.loc[new_lunch]
# Out:
#      gender race/ethnicity parental level of education         lunch  \
# 3      male        group A          associate's degree  free/reduced
# 7      male        group B                some college  free/reduced
# 8      male        group D                 high school  free/reduced
# 9    female        group B                 high school  free/reduced
# 17   female        group B            some high school  free/reduced
# ..      ...            ...                         ...           ...
# 992  female        group D          associate's degree  free/reduced
# 993  female        group D           bachelor's degree  free/reduced
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 999  female        group D                some college  free/reduced
#
#     test preparation course  math score  reading score  writing score
# ...

# %%
students_perdormance.loc[new_lunch].mean(axis='index')
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_12132\3864424382.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   students_perdormance.loc[new_lunch].mean(axis='index')
# math score       58.921127
# reading score    64.653521
# writing score    63.022535
# dtype: float64

# %%
students_perdormance.loc[new_lunch].var(axis='index')
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_12132\1691144227.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   students_perdormance.loc[new_lunch].var(axis='index')
# math score       229.824270
# reading score    221.871139
# writing score    238.202881
# dtype: float64

# %%
new_lunch_standard = (students_perdormance['lunch'] == 'standard')

# %%
students_perdormance.loc[new_lunch_standard].mean(axis='index')
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_12132\25784049.py:1: FutureWarning: The default value of numeric_only in DataFrame.mean is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   students_perdormance.loc[new_lunch_standard].mean(axis='index')
# math score       70.034109
# reading score    71.654264
# writing score    70.823256
# dtype: float64

# %%
students_perdormance.loc[new_lunch_standard].var(axis='index')
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_12132\959794558.py:1: FutureWarning: The default value of numeric_only in DataFrame.var is deprecated. In a future version, it will default to False. In addition, specifying 'numeric_only=None' is deprecated. Select only valid columns or specify the value of numeric_only to silence this warning.
#   students_perdormance.loc[new_lunch_standard].var(axis='index')
# math score       186.418089
# reading score    191.285560
# writing score    205.620887
# dtype: float64

# %%
students_perdormance.filter(like='score')
# Out:
#      math score  reading score  writing score
# 0            72             72             74
# 1            69             90             88
# 2            90             95             93
# 3            47             57             44
# 4            76             78             75
# ..          ...            ...            ...
# 995          88             99             95
# 996          62             55             55
# 997          59             71             65
# 998          68             78             77
# 999          77             86             86
#
# [1000 rows x 3 columns]

# %%
list(students_perdormance)
# Out:
# ['gender',
#  'race/ethnicity',
#  'parental_level_of_education',
#  'lunch',
#  'test_preparation_course',
#  'math_score',
#  'reading_score',
#  'writing_score']

# %%
students_perdormance = students_perdormance.rename(columns=
                                            {'parental level of education': 'parental_level_of_education',
                                            'test preparation course': 'test_preparation_course',
                                            'math score': 'math_score',
                                            'reading score': 'reading_score',
                                            'writing score': 'writing_score'})

# %%
avg_ms_score = 95

# %%
students_perdormance.query("gender == 'female' & math_score >= @avg_ms_score")
# Out:
#      gender race/ethnicity parental_level_of_education     lunch  \
# 114  female        group E           bachelor's degree  standard
# 165  female        group C           bachelor's degree  standard
# 179  female        group D            some high school  standard
# 263  female        group E                 high school  standard
# 451  female        group E                some college  standard
# 458  female        group E           bachelor's degree  standard
# 503  female        group E          associate's degree  standard
# 712  female        group D                some college  standard
# 717  female        group C          associate's degree  standard
# 855  female        group B           bachelor's degree  standard
# 962  female        group E          associate's degree  standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 114               completed          99            100            100
# ...

# %%
score = [i for i in list(students_perdormance) if 'score' in i]
score
# Out:
# ['math_score', 'reading_score', 'writing_score']

# %%
students_perdormance_whis_makes.filter(like='g', axis=1)
# Out:
#            gender  reading score  writing score
# gthdsq     female             72             74
# dnjhjq       male             57             44
# nhtnbq       male             78             75
# xtnd`hnsq    male             43             39
# gznsq        male             64             67

# %%
students_perdormance_whis_makes.filter(like='g', axis=0)
# Out:
#         gender race/ethnicity parental level of education         lunch  \
# gthdsq  female        group B           bachelor's degree      standard
# gznsq     male        group D                 high school  free/reduced
#
#        test preparation course  math score  reading score  writing score
# gthdsq                    none          72             72             74
# gznsq                completed          64             64             67

# %%
df = pd.read_csv('C:/Users/filip/ML/static//column_hell.csv')

# %%
selected_columns = df.filter(like = '-')
selected_columns
# Out:
#      umeca-4  kudbpyw-3       g-3       v-9     fla-6  hwtbyrkp-5
# 0   0.016124   0.430787  0.202407  0.725508  0.305076    0.979296
# 1   0.507115   0.671662  0.864249  0.867818  0.358859    0.160520
# 2   0.003274   0.286411  0.928865  0.719159  0.340235    0.734612
# 3   0.784139   0.863717  0.175446  0.554744  0.049325    0.621132
# 4   0.011265   0.206172  0.044151  0.163643  0.048806    0.437836
# ..       ...        ...       ...       ...       ...         ...
# 95  0.220817   0.434444  0.601738  0.146333  0.918888    0.216499
# 96  0.474131   0.176011  0.359793  0.104707  0.257690    0.066934
# 97  0.091637   0.871606  0.121075  0.907699  0.313184    0.788592
# 98  0.360106   0.172385  0.015285  0.019571  0.060751    0.403166
# 99  0.669284   0.701505  0.481430  0.024944  0.644989    0.702003
#
# [100 rows x 6 columns]

# %%
students_perdormance.groupby('gender').mean()
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_12132\2477778667.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   students_perdormance.groupby('gender').mean()
#         math_score  reading_score  writing_score
# gender
# female   63.633205      72.608108      72.467181
# male     68.728216      65.473029      63.311203

# %%
students_perdormance.groupby('gender', \
                             as_index=False).aggregate({'math_score': 'mean','reading_score': 'mean','writing_score': 'mean'}).rename(columns={'math_score':'mean_math_score'})
# Out:
#    gender  mean_math_score  reading_score  writing_score
# 0  female        63.633205      72.608108      72.467181
# 1    male        68.728216      65.473029      63.311203

# %%
students_perdormance.sort_values(['gender', 'math_score'], ascending=False).groupby('gender').head(5)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 149    male        group E          associate's degree  free/reduced
# 623    male        group A                some college      standard
# 625    male        group D                some college      standard
# 916    male        group E           bachelor's degree      standard
# 306    male        group E                some college      standard
# 451  female        group E                some college      standard
# 458  female        group E           bachelor's degree      standard
# 962  female        group E          associate's degree      standard
# 114  female        group E           bachelor's degree      standard
# 263  female        group E                 high school      standard
#
#     test_preparation_course  math_score  reading_score  writing_score
# 149               completed         100            100             93
# ...

# %%
students_perdormance['total_score'] = students_perdormance.math_score + students_perdormance.reading_score + students_perdormance.writing_score

# %%
students_perdormance
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
students_perdormance = students_perdormance.assign(total_score_log = np.log(students_perdormance.total_score))

# %%
students_perdormance.drop(['total_score_log'],axis=1)
# Out:
#      gender race/ethnicity parental_level_of_education         lunch  \
# 0    female        group B           bachelor's degree      standard
# 1    female        group C                some college      standard
# 2    female        group B             master's degree      standard
# 3      male        group A          associate's degree  free/reduced
# 4      male        group C                some college      standard
# ..      ...            ...                         ...           ...
# 995  female        group E             master's degree      standard
# 996    male        group C                 high school  free/reduced
# 997  female        group C                 high school  free/reduced
# 998  female        group D                some college      standard
# 999  female        group D                some college  free/reduced
#
#     test_preparation_course  math_score  reading_score  writing_score  \
# ...

# %%
dota_hero_stats = pd.read_csv('C:/Users/filip/ML/static//dota_hero_stats.csv')

# %%
dota_hero_stats
# Out:
#      Unnamed: 0 attack_type   id  legs  localized_name  \
# 0             0       Melee    1     2       Anti-Mage
# 1             1       Melee    2     2             Axe
# 2             2      Ranged    3     4            Bane
# 3             3       Melee    4     2     Bloodseeker
# 4             4      Ranged    5     2  Crystal Maiden
# ..          ...         ...  ...   ...             ...
# 112         112       Melee  114     2     Monkey King
# 113         113      Ranged  119     2     Dark Willow
# 114         114       Melee  120     2       Pangolier
# 115         115      Ranged  121     2      Grimstroke
# 116         116       Melee  129     2            Mars
#
#                              name primary_attr  \
# 0          npc_dota_hero_antimage          agi
# 1               npc_dota_hero_axe          str
# 2              npc_dota_hero_bane          int
# 3       npc_dota_hero_bloodseeker          agi
# 4    npc_dota_hero_crystal_maiden          int
# ...

# %%
legs_rate = dota_hero_stats.groupby('legs').count()
legs_rate
# Out:
#       Unnamed: 0  attack_type  id  localized_name  name  primary_attr  roles
# legs
# 0             11           11  11              11    11            11     11
# 2             95           95  95              95    95            95     95
# 4              7            7   7               7     7             7      7
# 6              3            3   3               3     3             3      3
# 8              1            1   1               1     1             1      1

# %%
dota_hero_stats.groupby(['attack_type', 'primary_attr'],as_index=False).count()
# Out:
#   attack_type primary_attr  Unnamed: 0  id  legs  localized_name  name  roles
# 0       Melee          agi          19  19    19              19    19     19
# 1       Melee          int           2   2     2               2     2      2
# 2       Melee          str          35  35    35              35    35     35
# 3      Ranged          agi          18  18    18              18    18     18
# 4      Ranged          int          40  40    40              40    40     40
# 5      Ranged          str           3   3     3               3     3      3

# %%
money_lupa_pupa = pd.read_csv('C:/Users/filip/ML/static//accountancy.csv')

# %%
money_lupa_pupa
# Out:
#     Unnamed: 0 Executor Type  Salary
# 0            0     Pupa    D      63
# 1            1     Pupa    A     158
# 2            2     Pupa    D     194
# 3            3     Pupa    E     109
# 4            4    Loopa    E     184
# 5            5    Loopa    F     232
# 6            6    Loopa    B     249
# 7            7     Pupa    F     195
# 8            8     Pupa    A     115
# 9            9     Pupa    E      65
# 10          10    Loopa    C     145
# 11          11    Loopa    D     149
# 12          12    Loopa    B      50
# 13          13     Pupa    A     217
# 14          14    Loopa    D     110
# 15          15     Pupa    F      62
# 16          16     Pupa    A      55
# 17          17    Loopa    B     190
# 18          18    Loopa    E      83
# 19          19     Pupa    A     234
# 20          20    Loopa    E     156
# 21          21    Loopa    E     219
# 22          22     Pupa    C      55
# 23          23     Pupa    D     144
# ...

# %%
sorted_l = money_lupa_pupa.groupby(['Type', 'Executor'],as_index=False).aggregate({'Salary': 'mean'})
sorted_l
# Out:
#    Type Executor      Salary
# 0     A    Loopa   58.000000
# 1     A     Pupa  160.833333
# 2     B    Loopa  145.166667
# 3     B     Pupa   77.000000
# 4     C    Loopa  154.333333
# 5     C     Pupa   74.500000
# 6     D    Loopa  137.714286
# 7     D     Pupa  146.500000
# 8     E    Loopa  164.000000
# 9     E     Pupa  131.200000
# 10    F    Loopa  238.000000
# 11    F     Pupa  136.250000

# %%
concentrations = pd.read_csv('C:/Users/filip/ML/static//algae.csv')

# %%
concentrations
# Out:
#                 species        genus  group   sucrose    alanin   citrate  \
# 0     Fucus_vesiculosus        Fucus  brown  3.001472  3.711498  5.004262
# 1   Saccharina_japonica   Saccharina  brown  6.731070  1.255251  5.621499
# 2        Fucus_serratus        Fucus  brown  3.276870  0.346431  1.216767
# 3       Fucus_distichus        Fucus  brown  6.786996  6.641303  6.423606
# 4     Cladophora_fracta   Cladophora  green  3.861470  1.648450  6.940588
# 5   Cladophora_compacta   Cladophora  green  5.712284  3.461692  3.082826
# 6   Cladophora_gracilis   Cladophora  green  2.452623  6.881024  5.841520
# 7      Palmaria_palmata     Palmaria    red  0.704580  3.176440  5.573905
# 8  Saccharina_latissima   Saccharina  brown  1.636122  5.793163  1.071920
# 9   Ascophyllum_nodosum  Ascophyllum  brown  6.825467  0.875429  5.253527
#
#     glucose  oleic_acid
# 0  2.548459    6.405165
# 1  6.013219    4.156700
# 2  3.623225    0.304573
# 3  2.272724    3.393203
# 4  2.316955    2.528886
# ...

# %%
mean_concentrations = concentrations.groupby('genus').mean()
mean_concentrations
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_22736\3795049919.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   mean_concentrations = concentrations.groupby('genus').mean()
#               sucrose    alanin   citrate   glucose  oleic_acid
# genus
# Ascophyllum  6.825467  0.875429  5.253527  3.414961    2.432526
# Cladophora   4.008792  3.997055  5.288311  2.800276    2.263472
# Fucus        4.355112  3.566411  4.214878  2.814803    3.367647
# Palmaria     0.704580  3.176440  5.573905  3.242090    2.245538
# Saccharina   4.183596  3.524207  3.346710  4.980594    4.487252

# %%
concentrations_alanin = round(concentrations.query("genus == 'Fucus'")['alanin'].describe(),2)
concentrations_alanin
# Out:
# count    3.00
# mean     3.57
# std      3.15
# min      0.35
# 25%      2.03
# 50%      3.71
# 75%      5.18
# max      6.64
# Name: alanin, dtype: float64

# %%
round(concentrations.groupby('group')['sucrose'].max() - concentrations.groupby('group')['sucrose'].min(), 2)
# Out:
# group
# brown    5.19
# green    3.26
# red      0.00
# Name: sucrose, dtype: float64

# %%
round(concentrations.groupby('group')['sucrose'].var(),2)
# Out:
# group
# brown    5.46
# green    2.67
# red       NaN
# Name: sucrose, dtype: float64

# %%
students_perdormance.math_score.hist()
# Out:
# <AxesSubplot: >

# %%
students_perdormance.plot.scatter(x='math_score', y='reading_score')
# Out:
# <AxesSubplot: xlabel='math_score', ylabel='reading_score'>

# %%
ax = sns.lmplot(x='math_score', y='reading_score', hue='gender',data=students_perdormance, fit_reg=False)
ax.set_xlabels('Math scores')
ax.set_ylabels('Reading scores')

# %%
data_pay = pd.read_csv('C:/Users/filip/ML/static//income.csv')

# %%
data_pay
# Out:
#             income
# 2018-11-30      20
# 2018-12-31      60
# 2019-01-31     180
# 2019-02-28     380
# 2019-03-31     660

# %%
data_pay.income.plot()
# Out:
# <AxesSubplot: >

# %%
data_pay.plot(kind='line')
# Out:
# <AxesSubplot: >

# %%
data_pay.plot()
# Out:
# <AxesSubplot: >

# %%
data_pay.plot(kind='line')
# Out:
# <AxesSubplot: >

# %%
data_pay['income'].plot()
# Out:
# <AxesSubplot: >

# %%
sns.lineplot(x=data_pay.index, y=data_pay.income)
# Out:
# <AxesSubplot: ylabel='income'>

# %%
sns.lineplot(data=data_pay)
# Out:
# <AxesSubplot: >

# %%
data_pay.plot()
# Out:
# <AxesSubplot: >

# %%
dataset = pd.read_csv('C:/Users/filip/ML/static//2.csv', sep=" ")

# %%
dataset
# Out:
#               x            y
# 0    399.259411    92.034368
# 1   1317.690162   497.590886
# 2    426.281922   105.186914
# 3   1312.514757   507.185718
# 4   1181.356263   992.906146
# 5    106.566695  1489.960161
# 6    698.353528   200.817390
# 7    300.778008   283.859665
# 8   1311.150269   518.718496
# 9    398.977314    94.387804
# 10   399.823937    89.203075
# 11  1292.561729   506.023801
# 12   695.374196   200.486640
# 13  1294.282351   479.787766
# 14   307.135449   314.586541
# 15   101.269525  1512.518409
# 16   701.220662   194.725765
# 17  1196.386019  1000.712022
# 18   104.978440  1510.799069
# 19  1305.963707   495.784944
# 20  1310.190741   501.803761
# 21    87.214841  1500.210937
# 22   399.177809    89.389344
# 23   305.602356   293.791319
# 24  1197.133546   993.481119
# 25   404.118029    87.277252
# 26    94.580587  1497.281838
# 27   708.582589   208.103764
# 28   724.693257   192.570360
# 29   406.279672   102.037924
# 30   410.830038   103.087519
# ...

# %%
sns.lmplot(x='x', y='y', data=dataset, fit_reg=False)

# %%
g = pd.read_csv('C:/Users/filip/ML/static//genome_matrix.csv').set_index('Unnamed: 0')
g
# Out:
#             species0  species1  species2  species3  species4
# Unnamed: 0
# species0    0.536029  0.920292  0.679708  0.840606  0.430842
# species1    0.920292  0.862417  0.887593  0.769754  0.203214
# species2    0.679708  0.887593  0.595156  0.003435  0.096052
# species3    0.840606  0.769754  0.003435  0.458870  0.029251
# species4    0.430842  0.203214  0.096052  0.029251  0.642109

# %%
sns.heatmap(g)
# Out:
# <AxesSubplot: ylabel='Unnamed: 0'>

# %%
new_dota_hero_stats = dota_hero_stats

# %%
count = []
for r in dota_hero_stats['roles']: count.append(len(r.split(',')))
new_dota_hero_stats['roles']= count

# %%
new_dota_hero_stats['roles'].mean()
# Out:
# 4.0

# %%
new_dota_hero_stats['roles'].hist()
# Out:
# <AxesSubplot: >

# %%
iris = pd.read_csv('C:/Users/filip/ML/static//iris.csv')

# %%
iris = sns.load_dataset("iris")
sns.kdeplot(data=iris)
# Out:
# <AxesSubplot: ylabel='Density'>

# %%
fl = iris.describe().T
fl['diff'] = fl['max']-fl['min']
fl
# Out:
#               count      mean       std  min  25%   50%  75%  max  diff
# sepal_length  150.0  5.843333  0.828066  4.3  5.1  5.80  6.4  7.9   3.6
# sepal_width   150.0  3.057333  0.435866  2.0  2.8  3.00  3.3  4.4   2.4
# petal_length  150.0  3.758000  1.765298  1.0  1.6  4.35  5.1  6.9   5.9
# petal_width   150.0  1.199333  0.762238  0.1  0.3  1.30  1.8  2.5   2.4

# %%
df = iris
for column in df:
    sns.kdeplot(df[column], label=f'{column} ({df[column].max() - df[column].min():.1f})', shade=True)
plt.legend()
# Out:
# C:\Users\filip\AppData\Local\Temp\ipykernel_22736\219736708.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[column], label=f'{column} ({df[column].max() - df[column].min():.1f})', shade=True)
# C:\Users\filip\AppData\Local\Temp\ipykernel_22736\219736708.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[column], label=f'{column} ({df[column].max() - df[column].min():.1f})', shade=True)
# C:\Users\filip\AppData\Local\Temp\ipykernel_22736\219736708.py:3: FutureWarning:
#
# `shade` is now deprecated in favor of `fill`; setting `fill=True`.
# This will become an error in seaborn v0.14.0; please update your code.
#
#   sns.kdeplot(df[column], label=f'{column} ({df[column].max() - df[column].min():.1f})', shade=True)
# ...

# %%
sns.violinplot(data=iris['petal_length'])

# %%
sns.pairplot(data=iris)

# %%
my_stat = pd.read_csv('C:/Users/filip/ML/static//my_stat.csv')
my_stat
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 4     0  10.0  B -1.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [500 rows x 4 columns]

# %%
subset_1 = my_stat.iloc[:10, [0,2]]
subset_1
# Out:
#    V1 V3
# 0   2  B
# 1  -1  B
# 2   0  A
# 3   2  A
# 4   0  B
# 5   2  A
# 6   0  A
# 7   1  A
# 8   0  B
# 9  -1  A

# %%
subset_2 = my_stat.iloc[:, [1,3]].drop(my_stat.index[[0,4]])
subset_2
# Out:
#        V2   V4
# 1     7.0  1.0
# 2    11.0  0.0
# 3    11.0  2.0
# 5    11.0  0.0
# 6     9.0  2.0
# ..    ...  ...
# 495   8.0 -1.0
# 496   8.0  1.0
# 497  11.0  2.0
# 498  11.0  2.0
# 499   8.0  1.0
#
# [498 rows x 2 columns]

# %%
subset_1 = my_stat.query("V1 > 0 & V3 == 'A'")
subset_1
# Out:
#      V1    V2 V3   V4
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# 7     1   9.0  A  1.0
# 10    1  10.0  A  1.0
# 13    1  12.0  A  3.0
# ..   ..   ... ..  ...
# 491   4   7.0  A  2.0
# 494   1  11.0  A  1.0
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 498   1  11.0  A  2.0
#
# [88 rows x 4 columns]

# %%
subset_2 = my_stat.query("V2 != 10 | V4 >= 1")
subset_2
# Out:
#      V1    V2 V3   V4
# 0     2  13.0  B  1.0
# 1    -1   7.0  B  1.0
# 2     0  11.0  A  0.0
# 3     2  11.0  A  2.0
# 5     2  11.0  A  0.0
# ..   ..   ... ..  ...
# 495   1   8.0  A -1.0
# 496   3   8.0  A  1.0
# 497  -1  11.0  B  2.0
# 498   1  11.0  A  2.0
# 499   0   8.0  B  1.0
#
# [447 rows x 4 columns]

# %%
my_stat['V5'] = my_stat['V1'] + my_stat['V4']

# %%
my_stat.iloc[25:35, :]
# Out:
#     session_value  group time  n_users   V5        V6
# 25              2   10.0    A      3.0  5.0  2.302585
# 26              2   12.0    A      1.0  3.0  2.484907
# 27              2    9.0    A      1.0  3.0  2.197225
# 28             -2   10.0    B      0.0 -2.0  2.302585
# 29              0    8.0    A      1.0  1.0  2.079442
# 30              0   11.0    B      2.0  2.0  2.397895
# 31             -3   11.0    B     -1.0 -4.0  2.397895
# 32             -3   10.0    B      2.0 -1.0  2.302585
# 33              0   12.0    B      1.0  1.0  2.484907
# 34              0   10.0    B      1.0  1.0  2.302585

# %%
my_stat = my_stat.assign(V6 = np.log(my_stat.V2))

# %%
my_stat = my_stat.rename(columns={'V1':'session_value', 'V2':'group', 'V3':'time', 'V4':'n_users'})

# %%
my_stat = my_stat.fillna(0)
medians = my_stat.query("n_users >= 0")['n_users'].median()
replaced = my_stat.query("n_users < 0")['n_users'].unique()
my_stat['n_users'] = my_stat['n_users'].replace(to_replace=replaced, value=medians)
# Out:
# Series([], Name: n_users, dtype: float64)

# %%
replaced = my_stat.query("n_users < 0")['n_users'].unique()
replaced
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[427], line 1
# ----> 1 replaced = my_stat.query("n_users < 0")['n_users'].unique()
#       2 replaced
#
# File ~\ML\venv\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'query'

# %%
my_stat = my_stat.query("n_users < 0")['n_users'].replace(to_replace=replaced, value=medians)
my_stat
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[426], line 1
# ----> 1 my_stat = my_stat.query("n_users < 0")['n_users'].replace(to_replace=replaced, value=medians)
#       2 my_stat
#
# File ~\ML\venv\Lib\site-packages\pandas\core\generic.py:5902, in NDFrame.__getattr__(self, name)
#    5895 if (
#    5896     name not in self._internal_names_set
#    5897     and name not in self._metadata
#    5898     and name not in self._accessors
#    5899     and self._info_axis._can_hold_identifiers_and_holds_name(name)
#    5900 ):
#    5901     return self[name]
# -> 5902 return object.__getattribute__(self, name)
#
# AttributeError: 'Series' object has no attribute 'query'

# %%
my_stat
# Out:
#      session_value  group time  n_users
# 0                2   13.0    B      1.0
# 1               -1    7.0    B      1.0
# 2                0   11.0    A      0.0
# 3                2   11.0    A      2.0
# 4                0   10.0    B     -1.0
# ..             ...    ...  ...      ...
# 495              1    8.0    A     -1.0
# 496              3    8.0    A      1.0
# 497             -1   11.0    B      2.0
# 498              1   11.0    A      2.0
# 499              0    8.0    B      1.0
#
# [500 rows x 4 columns]

# %%
mean_session_value_data = my_stat.groupby(['group'], as_index=False).agg({"session_value": "mean"}).rename(columns={"session_value":"mean_session_value"})
mean_session_value_data
# Out:
#    group  mean_session_value
# 0    5.0            0.000000
# 1    7.0            0.333333
# 2    8.0            0.633333
# 3    9.0            0.238938
# 4   10.0            0.065990
# 5   11.0           -0.081081
# 6   12.0           -0.078947
# 7   13.0            0.000000

# %%
groups.count()
# Out:
#        session_value  time  n_users
# group
# 5.0                1     1        1
# 7.0                3     3        3
# 8.0               30    30       30
# 9.0              113   113      113
# 10.0             197   197      197
# 11.0             111   111      111
# 12.0              38    38       38
# 13.0               7     7        7
